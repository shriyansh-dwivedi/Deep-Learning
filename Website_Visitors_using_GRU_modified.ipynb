# %%
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, GRU, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
import pandas as pd
import numpy as np

# Generate synthetic daily temperature data for Delhi (2015-2022)
np.random.seed(42)
dates = pd.date_range(start='2015-01-01', end='2022-12-31', freq='D')
n = len(dates)

# Simulate seasonal temperature pattern (Delhi climate)
day_of_year = np.array([d.timetuple().tm_yday for d in dates])
seasonal = 25 + 15 * np.sin(2 * np.pi * (day_of_year - 80) / 365)
noise = np.random.normal(0, 2, n)
temperature = seasonal + noise

df = pd.DataFrame({'Date': dates, 'Temperature': np.round(temperature, 2)})
print('Dataset created successfully!')
print(f'Total records: {len(df)}')
# Out:
# ...
# 100%|██████████| 34.9k/34.9k [00:00<00:00, 1.55MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/bobnau/daily-website-visitors/versions/1

# %%
df.head(10)
# Out:
# ['daily-website-visitors.csv']

# %%
print(df.shape)

# %%
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
#    Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0    1     Sunday            1  9/14/2014      2,146         1,582
# 1    2     Monday            2  9/15/2014      3,621         2,528
# 2    3    Tuesday            3  9/16/2014      3,698         2,630
# 3    4  Wednesday            4  9/17/2014      3,667         2,614
# 4    5   Thursday            5  9/18/2014      3,316         2,366
#
#   First.Time.Visits Returning.Visits
# 0             1,430              152
# 1             2,297              231
# 2             2,352              278
# 3             2,327              287
# 4             2,130              236

# %%
df.tail()
# Out:
# (2167, 8)

# %%
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2167 entries, 0 to 2166
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Row                2167 non-null   int64
#  1   Day                2167 non-null   object
#  2   Day.Of.Week        2167 non-null   int64
#  3   Date               2167 non-null   object
#  4   Page.Loads         2167 non-null   object
#  5   Unique.Visits      2167 non-null   object
#  6   First.Time.Visits  2167 non-null   object
#  7   Returning.Visits   2167 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 135.6+ KB
# None
#                Row  Day.Of.Week
# count  2167.000000  2167.000000
# mean   1084.000000     3.997231
# std     625.703338     2.000229
# min       1.000000     1.000000
# 25%     542.500000     2.000000
# 50%    1084.000000     4.000000
# 75%    1625.500000     6.000000
# max    2167.000000     7.000000
# Row                  0
# ...

# %% [markdown]
# # Select Required Columns

# %%
df['Date'] = pd.to_datetime(df['Date'])
data = df[['Date', 'Temperature']]
print(data.head())
# Out:
#         Date Unique.Visits
# 0 2014-09-14         1,582
# 1 2014-09-15         2,528
# 2 2014-09-16         2,630
# 3 2014-09-17         2,614
# 4 2014-09-18         2,366

# %% [markdown]
# # Plotting

# %%
plt.figure(figsize=(15,6))
plt.plot(data['Date'], data['Temperature'], color='tomato')
plt.title('Daily Temperature in Delhi (2015-2022)')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.show()

# %% [markdown]
# # Normalize Data

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data[['Temperature']])

# %% [markdown]
# # Create Sequences

# %%
import numpy as np

sequence_length = 30

X = []
y = []

for i in range(sequence_length, len(scaled_data)):
    X.append(scaled_data[i-sequence_length:i])
    y.append(scaled_data[i])

X = np.array(X)
y = np.array(y)

print(X.shape)
print(y.shape)
# Out:
# (2137, 30, 1)
# (2137, 1)

# %% [markdown]
# # Train Test Split

# %%
split = int(0.8 * len(X))

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

print(X_train.shape)
print(X_test.shape)
# Out:
# (1709, 30, 1)
# (428, 30, 1)

# %% [markdown]
# # Build GRU Model

# %%
model = Sequential()
model.add(GRU(64,
              return_sequences=True,
              input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(GRU(64))
model.add(Dense(1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Compile Model

# %%
model.compile(optimizer='adam',
              loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 30, 64)         │        12,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 64)             │        24,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 37,889 (148.00 KB)
#  Trainable params: 37,889 (148.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=30,
    batch_size=32,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0545 - val_loss: 0.0217
# Epoch 2/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0266 - val_loss: 0.0187
# Epoch 3/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0213 - val_loss: 0.0144
# Epoch 4/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0129 - val_loss: 0.0088
# Epoch 5/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0088 - val_loss: 0.0071
# Epoch 6/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0072 - val_loss: 0.0065
# Epoch 7/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0044 - val_loss: 0.0034
# Epoch 8/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 9/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0026 - val_loss: 0.0035
# Epoch 10/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 11/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 12/30
# ...

# %% [markdown]
# # Plot Training Loss

# %%
plt.figure(figsize=(10,5))

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.legend()
plt.title("Loss Graph")
plt.show()

# %% [markdown]
# # Prediction

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
actual = scaler.inverse_transform(y_test)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
last_30_days = scaled_data[-sequence_length:]

last_30_days = last_30_days.reshape(1, sequence_length, 1)

next_day = model.predict(last_30_days)

next_day = scaler.inverse_transform(next_day)

print('Predicted Next Day Temperature (°C):', round(next_day[0][0], 2))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted Next Day Visitors: 1599.4576

# %% [markdown]
# # Plot Actual VS Predicted

# %%
plt.figure(figsize=(15,6))

plt.plot(actual, label='Actual Temperature', color='blue')
plt.plot(predictions, label='Predicted Temperature', color='red')

plt.legend()
plt.title('Actual vs Predicted Daily Temperature')
plt.ylabel('Temperature (°C)')
plt.show()
